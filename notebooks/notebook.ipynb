# %% [markdown]
# # Análise Comparativa de Criptomoedas
#
# Análise de Bitcoin, Ethereum e Solana com foco em:
# - Retorno acumulado
# - Volatilidade
# - Relação risco-retorno

# %% [markdown]
# ## Metodologia
#
# Os dados foram coletados via API pública e passaram por um pipeline de:
#
# 1. Coleta de dados (raw)
# 2. Tratamento e cálculo de retorno diário
# 3. Cálculo de métricas estatísticas
# 4. Consolidação e ranking comparativo
#
# Os resultados foram exportados para a pasta `data/results`.

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("ggplot")

# %%
df = pd.read_csv("../data/results/crypto_metrics.csv", index_col=0)

df
# Out:
#           cumulative_return  volatility  sharpe_ratio
# bitcoin           -0.288962    0.460421     -0.509561
# ethereum          -0.261486    0.783366      0.001609
# solana            -0.548699    0.852935     -0.505179

# %%
df_plot = df.copy()


df_plot.index = ["Bitcoin", "Ethereum", "Solana"]

df_plot["cumulative_return"] = df_plot["cumulative_return"] * 100
df_plot["volatility"] = df_plot["volatility"] * 100

df_plot = df_plot.rename(columns={
    "cumulative_return": "Retorno Acumulado (%)",
    "volatility": "Volatilidade (%)",
    "sharpe_ratio": "Índice de Sharpe"
})

df_plot
# Out:
#           Retorno Acumulado (%)  Volatilidade (%)  Índice de Sharpe
# Bitcoin              -28.896168         46.042146         -0.509561
# Ethereum             -26.148648         78.336594          0.001609
# Solana               -54.869875         85.293453         -0.505179

# %%
df_sorted = df_plot.sort_values("Retorno Acumulado (%)", ascending=False)

plt.figure(figsize=(8, 5))

plt.bar(df_sorted.index, df_sorted["Retorno Acumulado (%)"])

plt.title("Ranking de Retorno Acumulado")
plt.ylabel("Retorno (%)")
plt.xlabel("Criptomoeda")

plt.xticks(rotation=0)
plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.tight_layout()
plt.show()

# %%
df_sorted_risk = df_plot.sort_values("Volatilidade (%)", ascending=False)

plt.figure(figsize=(8, 5))

plt.bar(df_sorted_risk.index, df_sorted_risk["Volatilidade (%)"])

plt.title("Ranking de Volatilidade")
plt.ylabel("Volatilidade (%)")
plt.xlabel("Criptomoeda")

plt.xticks(rotation=0)
plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.scatter(
    df_plot["Volatilidade (%)"],
    df_plot["Retorno Acumulado (%)"]
)

for idx in df_plot.index:
    plt.annotate(
        idx,
        (
            df_plot.loc[idx, "Volatilidade (%)"],
            df_plot.loc[idx, "Retorno Acumulado (%)"]
        )
    )

plt.axhline(0)
plt.axvline(0)

plt.xlabel("Volatilidade (%)")
plt.ylabel("Retorno Acumulado (%)")
plt.title("Risco vs Retorno")

plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Interpretação dos Resultados
#
# - Ethereum apresentou o melhor desempenho relativo no período.
# - Solana apresentou maior volatilidade.
# - Bitcoin demonstrou menor risco comparado às demais.
# - Nenhum ativo apresentou retorno positivo no período analisado.
